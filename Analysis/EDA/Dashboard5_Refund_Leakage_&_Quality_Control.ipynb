# %% [markdown]
# ## Call Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Load Data

# %%
fact_sales = pd.read_csv('/content/fact_sales (1).csv')
dim_date = pd.read_csv('/content/dim_date.csv')
dim_product = pd.read_csv('/content/dim_product.csv')
dim_market = pd.read_csv('/content/dim_marketplace.csv')

# %% [markdown]
# ## Explore the tables

# %%
fact_sales.head()
# Out:
#    Sales_Key  Date_Key  Marketplace_Key  Product_Key Account Title  Taxes  \
# 0          1         1                1            1   [ UK ] Aava -50.34
# 1          2         2                1            1   [ UK ] Aava -58.89
# 2          3         3                1            1   [ UK ] Aava -72.41
# 3          4         4                1            1   [ UK ] Aava -41.43
# 4          5         5                1            1   [ UK ] Aava -47.04
#
#    Orders  Units  Refunded  Refund %  ...  Impressions  Clicks  PPC Orders  \
# 0      17     17         0       0.0  ...         3423      13           2
# 1      20     20         0       0.0  ...         2786       7           0
# 2      18     24         0       0.0  ...         2927       7           1
# 3      13     14         0       0.0  ...         3584      16           2
# 4      16     16         0       0.0  ...         4329       7           0
#
#    PPC Sales  PPC Cost  PPC Conv  OOE  Net Profit  Net Margin  Net ROI
# 0      29.36    -13.06    0.1538    0       56.28      0.1852   0.3142
# 1       0.00     -7.33    0.0000    0       71.73      0.2034   0.3439
# 2      14.69     -6.15    0.1429    0       61.37      0.1386   0.2416
# 3      44.07    -16.51    0.1250    0       39.49      0.1573   0.2684
# 4       0.00     -4.47    0.0000    0       59.86      0.2116   0.3588
#
# [5 rows x 30 columns]

# %%
dim_date.head()
# Out:
#    Date_Key        Date  Day  Month Month_Name  Quarter  Year  Week_Of_Year  \
# 0         1  2020-10-01    1     10    October        4  2020            40
# 1         2  2020-10-02    2     10    October        4  2020            40
# 2         3  2020-10-03    3     10    October        4  2020            40
# 3         4  2020-10-04    4     10    October        4  2020            40
# 4         5  2020-10-05    5     10    October        4  2020            41
#
#    Day_Name  Is_Weekend
# 0  Thursday       False
# 1    Friday       False
# 2  Saturday        True
# 3    Sunday        True
# 4    Monday       False

# %%
dim_product.head()
# Out:
#    Product_Key                             SKU       FNSKU        ASIN  \
# 0            1  UK_Aava_Magnesium_400mg_120_05  X000JJIQ79  B01GU9QLZC
# 1            2     UK_Aava_Omega_2000mg_120_05  X000JFSY57  B01GU9P0M2
# 2            3  UK_Aava_Turmeric_1400mg_120_07  X000J6KEPJ  B01GU8L68A
# 3            4  FR_Aava_Turmeric_1400mg_180_01  X000UL0561  B07CXYM3H5
# 4            5  FR_Aava_Magnesium_400mg_120_01  X000UL0OUX  B07CZ1P4BM
#
#   Parent ASIN  Is Parent     Brand  \
# 0   No Parent          0  Aavalabs
# 1   No Parent          0  Aavalabs
# 2   No Parent          0  Aavalabs
# 3   No Parent          0  Aavalabs
# 4   No Parent          0  Aavalabs
#
#                                                Title
# 0  High Absorption Magnesium Citrate Supplements ...
# 1  Omega 3 2000mg Fish Oil Capsules - High Streng...
# 2  Turmeric Curcumin Capsules with Black Pepper [...
# 3  Gélules biodisponibles du complexe de curcumin...
# 4  Citrate de Magnésium - 1496 mg dont 448,8 mg d...

# %%
dim_market.head()
# Out:
#    Marketplace_Key Market Place Account Title
# 0                1           UK   [ UK ] Aava
# 1                2           FR   [ FR ] Aava
# 2                3           DE   [ DE ] Aava
# 3                4           IT   [ IT ] Aava
# 4                5           ES   [ ES ] Aava

# %%
print(fact_sales.shape)
print(dim_date.shape)
print(dim_product.shape)
print(dim_market.shape)
# Out:
# (13323, 30)
# (209, 10)
# (102, 8)
# (5, 3)

# %%
fact_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13323 entries, 0 to 13322
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sales_Key         13323 non-null  int64
#  1   Date_Key          13323 non-null  int64
#  2   Marketplace_Key   13323 non-null  int64
#  3   Product_Key       13323 non-null  int64
#  4   Account Title     13323 non-null  object
#  5   Taxes             13323 non-null  float64
#  6   Orders            13323 non-null  int64
#  7   Units             13323 non-null  int64
#  8   Refunded          13323 non-null  int64
#  9   Refund %          13323 non-null  float64
#  10  Unit Session %    13323 non-null  float64
#  11  Promo Units       13323 non-null  int64
#  12  Organic Units     13323 non-null  int64
#  13  Per Unit Revenue  13323 non-null  float64
#  14  Revenue           13323 non-null  float64
#  15  COGS              13323 non-null  float64
#  16  FBA Fees          13323 non-null  float64
#  17  Promo Amount      13323 non-null  float64
#  18  Sessions          13323 non-null  int64
#  19  Page Views        13323 non-null  int64
#  20  Impressions       13323 non-null  int64
#  21  Clicks            13323 non-null  int64
#  22  PPC Orders        13323 non-null  int64
#  23  PPC Sales         13323 non-null  float64
#  24  PPC Cost          13323 non-null  float64
#  25  PPC Conv          13323 non-null  float64
#  26  OOE               13323 non-null  int64
#  27  Net Profit        13323 non-null  float64
#  28  Net Margin        13323 non-null  float64
#  29  Net ROI           13323 non-null  float64
# dtypes: float64(14), int64(15), object(1)
# memory usage: 3.0+ MB

# %%
fact_sales.isnull().sum()
# Out:
# Sales_Key           0
# Date_Key            0
# Marketplace_Key     0
# Product_Key         0
# Account Title       0
# Taxes               0
# Orders              0
# Units               0
# Refunded            0
# Refund %            0
# Unit Session %      0
# Promo Units         0
# Organic Units       0
# Per Unit Revenue    0
# Revenue             0
# COGS                0
# FBA Fees            0
# Promo Amount        0
# Sessions            0
# Page Views          0
# Impressions         0
# Clicks              0
# PPC Orders          0
# PPC Sales           0
# PPC Cost            0
# PPC Conv            0
# OOE                 0
# Net Profit          0
# Net Margin          0
# Net ROI             0
# dtype: int64

# %%
fact_sales.describe()
# Out:
#           Sales_Key      Date_Key  Marketplace_Key   Product_Key  \
# count  13323.000000  13323.000000     13323.000000  13323.000000
# mean    6662.000000    106.820011         3.011409     50.032425
# std     3846.163153     60.476180         1.417455     30.231676
# min        1.000000      1.000000         1.000000      1.000000
# 25%     3331.500000     54.000000         2.000000     26.000000
# 50%     6662.000000    108.000000         3.000000     48.000000
# 75%     9992.500000    160.000000         4.000000     80.000000
# max    13323.000000    209.000000         5.000000    102.000000
#
#               Taxes        Orders         Units      Refunded      Refund %  \
# count  13323.000000  13323.000000  13323.000000  13323.000000  13323.000000
# mean     -21.696464     11.346093     13.298581      0.258650      0.017083
# std       35.902825     16.978017     20.305648      1.237357      0.080636
# min    -1168.650000      0.000000      0.000000      0.000000      0.000000
# 25%      -25.190000      2.000000      3.000000      0.000000      0.000000
# 50%       -9.460000      7.000000      8.000000      0.000000      0.000000
# 75%       -1.980000     14.000000     16.000000      0.000000      0.000000
# max        0.000000    955.000000    975.000000     42.000000      1.055600
#
#        Unit Session %  ...    Impressions        Clicks    PPC Orders  \
# count    13323.000000  ...   13323.000000  13323.000000  13323.000000
# mean         0.134443  ...    4165.734819     15.582376      2.331757
# std          0.221282  ...    6593.383509     25.220657      4.106758
# min          0.000000  ...       0.000000      0.000000      0.000000
# 25%          0.000000  ...     537.000000      2.000000      0.000000
# 50%          0.000000  ...    1917.000000      7.000000      1.000000
# 75%          0.250000  ...    5036.500000     18.000000      3.000000
# max          7.000000  ...  121882.000000    713.000000    135.000000
#
#           PPC Sales      PPC Cost      PPC Conv      OOE    Net Profit  \
# count  13323.000000  13323.000000  13323.000000  13323.0  13323.000000
# mean      51.895073    -15.246775      0.144013      0.0     61.224216
# std       94.217849     26.139957      0.258420      0.0    110.080049
# min        0.000000  -1064.850000      0.000000      0.0   -486.310000
# 25%        0.000000    -17.230000      0.000000      0.0      5.350000
# 50%       18.170000     -6.330000      0.076900      0.0     24.960000
# 75%       63.610000     -1.140000      0.200000      0.0     65.095000
# max     2875.440000      0.000000      6.000000      0.0   2342.190000
#
#          Net Margin       Net ROI
# count  1.332300e+04  13323.000000
# mean   2.414762e+11      0.294288
# std    1.278643e+14      0.308586
# min   -8.702340e+15     -2.940700
# 25%    7.945000e-02      0.115350
# 50%    1.903000e-01      0.291900
# 75%    2.651000e-01      0.439600
# max    1.191953e+16      2.695400
#
# [8 rows x 29 columns]

# %%
dim_date.columns.tolist()
# Out:
# ['Date_Key',
#  'Date',
#  'Day',
#  'Month',
#  'Month_Name',
#  'Quarter',
#  'Year',
#  'Week_Of_Year',
#  'Day_Name',
#  'Is_Weekend']

# %% [markdown]
# ## Data Merge

# %%
sales = fact_sales.merge(
    dim_date,
    on='Date_Key',
    how='left'
)

sales = sales.merge(
    dim_product,
    on='Product_Key',
    how='left'
)

sales = sales.merge(
    dim_market,
    on='Marketplace_Key',
    how='left'
)

sales.head()
# Out:
#    Sales_Key  Date_Key  Marketplace_Key  Product_Key Account Title_x  Taxes  \
# 0          1         1                1            1     [ UK ] Aava -50.34
# 1          2         2                1            1     [ UK ] Aava -58.89
# 2          3         3                1            1     [ UK ] Aava -72.41
# 3          4         4                1            1     [ UK ] Aava -41.43
# 4          5         5                1            1     [ UK ] Aava -47.04
#
#    Orders  Units  Refunded  Refund %  ...  Is_Weekend  \
# 0      17     17         0       0.0  ...       False
# 1      20     20         0       0.0  ...       False
# 2      18     24         0       0.0  ...        True
# 3      13     14         0       0.0  ...        True
# 4      16     16         0       0.0  ...       False
#
#                               SKU       FNSKU        ASIN  Parent ASIN  \
# 0  UK_Aava_Magnesium_400mg_120_05  X000JJIQ79  B01GU9QLZC    No Parent
# 1  UK_Aava_Magnesium_400mg_120_05  X000JJIQ79  B01GU9QLZC    No Parent
# 2  UK_Aava_Magnesium_400mg_120_05  X000JJIQ79  B01GU9QLZC    No Parent
# 3  UK_Aava_Magnesium_400mg_120_05  X000JJIQ79  B01GU9QLZC    No Parent
# 4  UK_Aava_Magnesium_400mg_120_05  X000JJIQ79  B01GU9QLZC    No Parent
#
#    Is Parent     Brand                                              Title  \
# 0          0  Aavalabs  High Absorption Magnesium Citrate Supplements ...
# 1          0  Aavalabs  High Absorption Magnesium Citrate Supplements ...
# 2          0  Aavalabs  High Absorption Magnesium Citrate Supplements ...
# 3          0  Aavalabs  High Absorption Magnesium Citrate Supplements ...
# 4          0  Aavalabs  High Absorption Magnesium Citrate Supplements ...
#
#    Market Place  Account Title_y
# 0            UK      [ UK ] Aava
# 1            UK      [ UK ] Aava
# 2            UK      [ UK ] Aava
# 3            UK      [ UK ] Aava
# 4            UK      [ UK ] Aava
#
# [5 rows x 48 columns]

# %%
sales.shape
# Out:
# (13323, 48)

# %%
sales.columns.tolist()
# Out:
# ['Sales_Key',
#  'Date_Key',
#  'Marketplace_Key',
#  'Product_Key',
#  'Account Title_x',
#  'Taxes',
#  'Orders',
#  'Units',
#  'Refunded',
#  'Refund %',
#  'Unit Session %',
#  'Promo Units',
#  'Organic Units',
#  'Per Unit Revenue',
#  'Revenue',
#  'COGS',
#  'FBA Fees',
#  'Promo Amount',
#  'Sessions',
#  'Page Views',
#  'Impressions',
#  'Clicks',
#  'PPC Orders',
#  'PPC Sales',
#  'PPC Cost',
#  'PPC Conv',
#  'OOE',
#  'Net Profit',
#  'Net Margin',
#  'Net ROI',
#  'Date',
#  'Day',
#  'Month',
#  'Month_Name',
#  'Quarter',
#  'Year',
#  'Week_Of_Year',
#  'Day_Name',
#  'Is_Weekend',
#  'SKU',
#  'FNSKU',
#  'ASIN',
#  'Parent ASIN',
#  'Is Parent',
#  'Brand',
#  'Title',
#  'Market Place',
#  'Account Title_y']

# %%
sales['Year'].value_counts()
# Out:
# Year
# 2021    7623
# 2020    5700
# Name: count, dtype: int64

# %% [markdown]
# #Explore The Best KPIs

# %% [markdown]
# ##1-Total Refunded Units

# %%
total_refunded = sales['Refunded'].sum()
total_refunded
# Out:
# np.int64(3446)

# %% [markdown]
# ## 2-Refund Rate

# %%
refund_rate = (
    sales['Refunded'].sum() /
    sales['Units'].sum()
) * 100

print(f"Refund Rate: {refund_rate:.2f}%")
# Out:
# Refund Rate: 1.94%

# %% [markdown]
# ## 3-High-Risk SKUs

# %%
sku_refund = sales.groupby('SKU').agg({
    'Refunded':'sum',
    'Units':'sum'
})

sku_refund['Refund_Rate'] = (
    sku_refund['Refunded'] /
    sku_refund['Units']
) * 100

avg_refund_rate = (
    sales['Refunded'].sum() /
    sales['Units'].sum()
) * 100

high_risk_skus = (
    sku_refund['Refund_Rate'] > avg_refund_rate
).sum()

print(high_risk_skus)
# Out:
# 18

# %% [markdown]
# ## 4-Revenue Lost Due to Refunds

# %%
sales['Revenue_Lost'] = (
    sales['Refunded'] *
    sales['Per Unit Revenue']
)

revenue_lost = sales['Revenue_Lost'].sum()

print(f"${revenue_lost:,.2f}")
# Out:
# $109,521.69

# %% [markdown]
# # Data Visulaization

# %% [markdown]
# ## Prepar the data

# %%
sales['Refund_Cost_Impact'] = (
    sales['Refunded'] *
    sales['Per Unit Revenue']
)

monthly_refund = sales.groupby(
    ['Year', 'Month', 'Month_Name'],
    as_index=False
)['Refund_Cost_Impact'].sum()

monthly_refund = monthly_refund.sort_values(
    ['Year', 'Month']
)

monthly_refund['Month_Year'] = (
    monthly_refund['Month_Name']
    + '-'
    + monthly_refund['Year'].astype(str)
)

# %% [markdown]
# ##Chart 1: Financial Impact of Refunds Over Time (Area Chart)

# %%
import pandas as pd
import plotly.express as px

sales['Refund_Cost_Impact'] = (
    sales['Refunded'].fillna(0) *
    sales['Per Unit Revenue'].fillna(0)
)

monthly_refund = sales.groupby(
    ['Year', 'Month'],
    as_index=False
)['Refund_Cost_Impact'].sum()

monthly_refund = monthly_refund.sort_values(['Year', 'Month'])

monthly_refund['Month_Year'] = pd.to_datetime(
    monthly_refund['Year'].astype(str) + '-' +
    monthly_refund['Month'].astype(str) + '-01'
)

fig = px.area(
    monthly_refund,
    x='Month_Year',
    y='Refund_Cost_Impact',
    markers=True,
    title='Financial Impact of Refunds Over Time',
    labels={
        'Month_Year': 'Month',
        'Refund_Cost_Impact': 'Revenue Lost Due to Refunds ($)'
    }
)

fig.update_layout(
    title_x=0.5,
    template='plotly_white',
    hovermode='x unified',
    height=600
)

fig.update_traces(
    hovertemplate='Date: %{x|%Y-%m}<br>Refund Loss: $%{y:,.2f}'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f0c06977-4655-4375-ba2f-f41f3c52a6bb" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0c06977-4655-4375-ba2f-f41f3c52a6bb")) {                    Plotly.newPlot(                        "f0c06977-4655-4375-ba2f-f41f3c52a6bb",                        [{"fillpattern":{"shape":""},"hovertemplate":"Date: %{x|%Y-%m}\u003cbr\u003eRefund Loss: $%{y:,.2f}","legendgroup":"","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":["2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00"],"xaxis":"x","y":[57345.479999999996,15951.21,7435.35,9920.87,7206.73,8402.21,3259.84],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"col ...

# %% [markdown]
# ##Worst Offenders: Refund % by SKU Horizontal Bar Chart

# %%
import pandas as pd
import plotly.express as px

sku_refund = sales.groupby('SKU', as_index=False).agg({
    'Refunded': 'sum',
    'Units': 'sum'
})

sku_refund['Refund_Rate'] = (
    sku_refund['Refunded'] / sku_refund['Units']
).fillna(0) * 100

top_refund_skus = sku_refund.sort_values(
    'Refund_Rate',
    ascending=False
).head(10)

avg_refund_rate = (
    sales['Refunded'].sum() /
    sales['Units'].sum()
) * 100

fig = px.bar(
    top_refund_skus,
    x='Refund_Rate',
    y='SKU',
    orientation='h',
    title='Worst Offenders: Refund % by SKU',
    labels={
        'Refund_Rate': 'Refund Rate (%)',
        'SKU': 'SKU'
    }
)

fig.add_vline(
    x=avg_refund_rate,
    line_dash='dash',
    annotation_text=f'Average = {avg_refund_rate:.2f}%',
    annotation_position='top'
)

fig.update_layout(
    template='plotly_white',
    title_x=0.5,
    height=600,
    yaxis={'categoryorder': 'total ascending'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e3f30d9a-194e-4bd0-a9ab-bd12090f6850" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3f30d9a-194e-4bd0-a9ab-bd12090f6850")) {                    Plotly.newPlot(                        "e3f30d9a-194e-4bd0-a9ab-bd12090f6850",                        [{"alignmentgroup":"True","hovertemplate":"Refund Rate (%)=%{x}\u003cbr\u003eSKU=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[93.92265193370166,92.75,6.122448979591836,4.827586206896552,4.225352112676056,4.0,2.761506276150628,2.613129381771829,2.601734489659773,2.479701558042572],"xaxis":"x","y":["NL_Magnesium_120","NL_Aava_Omega_2000mg_120_01","FR_Aava_Leanergy_90_02","DE_Aava_Beauty_90_01","FR_Aava_Spirulina_Chlorella_700_180_01","FR_Aava_Beta_Caroten_25_180_01","FR_Aava_Triple_Zinc_180_01","FR_Aava_Magnesium_400mg_120_01","FR_Aava_D3_5000iu_360_01","ES_Aava_D3_5000iu_360_01"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0 ...

# %% [markdown]
# ##Chart 3: Refunds vs Net Margin Correlation (Scatter Plot)

# %%
sku_margin = sales.groupby('SKU').agg({
    'Refunded':'sum',
    'Units':'sum',
    'Net Profit':'sum',
    'Revenue':'sum'
}).reset_index()

sku_margin['Refund_Rate'] = (
    sku_margin['Refunded'] /
    sku_margin['Units']
) * 100

sku_margin['Net_Margin_Pct'] = (
    sku_margin['Net Profit'] /
    sku_margin['Revenue']
) * 100

# %%
sku_margin = sku_margin[
    sku_margin['Units'] >= 100
]

# %%
import plotly.express as px

fig = px.scatter(
    sku_margin,
    x='Refund_Rate',
    y='Net_Margin_Pct',
    hover_data=['SKU'],
    title='Refund Rate vs Net Margin'
)

fig.update_layout(
    template='plotly_white',
    title_x=0.5,
    xaxis_title='Refund Rate (%)',
    yaxis_title='Net Margin (%)',
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="58e8ce80-3c97-4500-b6c4-52dc6dcee997" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58e8ce80-3c97-4500-b6c4-52dc6dcee997")) {                    Plotly.newPlot(                        "58e8ce80-3c97-4500-b6c4-52dc6dcee997",                        [{"customdata":[["DE_Aava_Beauty_90_01"],["DE_Aava_Beta_Caroten_25_180_01"],["DE_Aava_D3_5000iu_360_01"],["DE_Aava_Fullnesium_180_01"],["DE_Aava_Leanergy_90_02"],["DE_Aava_Maca_180_01"],["DE_Aava_Premium_Probiolac_90_02"],["DE_Aava_Probiotic_10B_60_01"],["DE_Aava_Spirulina_Chlorella_700_180_01"],["DE_Aava_Triple_Zinc_180_01"],["DE_Aava_Vegan_O3_60_02"],["DE_Aava_Vitamin_B_Complex_180_03"],["DE_Aava_Vitamin_C_180_01"],["DE_Magnesium_120"],["DE_Turmeric_500_120"],["De_Aava_Omega_2000mg_120_01"],["ES_Aava_Beauty_90_01"],["ES_Aava_Beta_Caroten_25_180_01"],["ES_Aava_D3_5000iu_360_01"],["ES_Aava_Fullnesium_180_01"],["ES_Aava_Leanergy_90_02"],["ES_Aava_Magnesium_400mg_120_01"],["ES_Aava_Omega_2000mg_120_01"],["ES_Aava_Premium_Probiolac_90_03"],["ES_Aava_Probiotic_10B_60_01"],["ES_Aava_Spirulina_Chlorella_700_180_01"],["ES_Aava_Triple_Zinc_180_02"],["ES_Aava_Turmeric_1400mg_180_01"],["ES_Aava_Vegan_O3_120_02"],["ES_Aava_Vitamin_B_Complex_180_02"],["ES_Aava_Vitamin_C_180_01"],["FR_Aava_Beauty_90_01"],["FR_Aava_D3_5000iu_360_01"],["FR_Aava_Fullnesium_180_01"],["FR_Aava_Magnesium_400mg_120_01"],["FR_Aava_Omega_2000mg_120_01"],["FR_Aava_Premium_Probiolac_90_02"],["FR_Aava_Probiotic_60_01"],["FR_Aava_Spirulina_Chlorella_700_180_01"],["FR_Aava_Triple_Zinc_180_01"],["FR_Aava_Turmeric_1400mg_180_01"],["FR_Aava_Vitamin_B_Complex_180_03"],["FR_Aava_Vitamin_C_180_01"],["IT_Aava_Beta_Caroten_25_180_01"],["IT_Aava_D3_5000iu_360_01"],["IT_Aava_Fullnesium_180_01"],["IT_Aava_Leanergy_90"],["IT_Aava_Magnesium_400mg_120_01"],["IT_Aava_Omega_2000mg_120_01"],["IT_Aava_Premium_Probiolac_90"],["IT_Aava_Probiotic_60_01"],["IT_Aava_Spirulina_Chlorella_700_180_01"],["IT_Aava_Triple_Zinc_180_01"],["IT_Aava_Turmeric_1400mg_180_01"],["IT_Aava_Vitamin_B_Complex_180_02"],["IT_Aava_Vitamin_C_180_01"],["NL_Aava_Omega_2000mg_120_01"],["NL_Magnesium_120"],["UK_Aava_Beauty_90_01"],["UK_Aava_Fullnesium_180_02"],["UK_Aava_Maca_180_01"],["UK_Aava_Magnesium_400mg_120_05"],["UK_Aava_Omega_2000mg_120_05"],["UK_Aava_Premium_Probiolac_90_02"],["UK_Aava_Probiotic_10B_60_01"],["UK_Aava_Spirulina_180_01"],["UK_Aava_Triple_Zinc_180_01"],["UK_Aava_Turmeric_1400mg_120_07"],["UK_Aava_Vegan_O3_120_04"],["UK_Aava_Vitamin_B_Complex_180_02"],["UK_Aava_Vitamin_C_180_01"]],"hovertemplate":"Refund_Rate=%{x}\u003cbr\u003eNet_Margin_Pct=%{y}\u003cbr\u003eSKU=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[4.827586206896552,1.8539200357382175,1.905356863970014,1.192368839427663,1.0204081632653061,2.3255813953488373,1.7817371937639197,1.7719218537028625,1.6957605985037407,1.1677934849416103,1.8276762402088773,1.2013729977116705,1.2308533916849016,1.7149984409105083,1.6695451928612552,1.3758766529257453,1.461988304093567,1.0362694300518136,2.479701558042572,1.0644589000591367,1.5965166908563133,1.6250303177298082,1.6449557858704955,1.9738528582414765,1.6173570019723866,1.430976430976431,1.3107591480065537,1.6941596076683014,2.4271844660194173,2.1435228331780056,2.0647583294228062,1.1904761904761905,2.601734489659773,1.6483516483516485,2.613129381771829,1.530612244897959,2.0994001713796058,2.2641509433962264,4.225352112676056,2.761506276150628,2.1,0.7462686567164178,0.8547008547008548,0.4022526146419952,1.3534781240163676,0.8791208791208791,0.8620689655172413,1.544943820224719,0.9814763616256565,0.990752 ...

# %% [markdown]
# ##4-Refund Cost Impact by Marketplace

# %%
market_refund = sales.groupby('Market Place', as_index=False)[
    'Refund_Cost_Impact'
].sum()

market_refund = market_refund.sort_values(
    'Refund_Cost_Impact',
    ascending=False
)

# %%
fig = px.bar(
    market_refund,
    x='Market Place',
    y='Refund_Cost_Impact',
    title='Refund Cost Impact by Marketplace'
)

fig.update_layout(
    template='plotly_white',
    title_x=0.5
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3a13c633-b4cb-4a4f-974f-3a607a1997e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a13c633-b4cb-4a4f-974f-3a607a1997e2")) {                    Plotly.newPlot(                        "3a13c633-b4cb-4a4f-974f-3a607a1997e2",                        [{"alignmentgroup":"True","hovertemplate":"Market Place=%{x}\u003cbr\u003eRefund_Cost_Impact=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["DE","ES","UK","IT","FR"],"xaxis":"x","y":[70416.57,20122.5,7701.35,6814.08,4467.19],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colo ...
