# %% [markdown]
# # Call Library & Import File

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/DailySales.xlsx')

# %% [markdown]
# #Data Exploration & Cleaning

# %%
df.shape
# Out:
# (13324, 34)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13324 entries, 0 to 13323
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              13323 non-null  datetime64[ns]
#  1   Title             13233 non-null  object
#  2   Account Title     13323 non-null  object
#  3   Market Place      13323 non-null  object
#  4   SKU               13323 non-null  object
#  5   FNSKU             13323 non-null  object
#  6   ASIN              13284 non-null  object
#  7   Parent ASIN       2130 non-null   object
#  8   Is Parent         13323 non-null  float64
#  9   Internal Name     0 non-null      float64
#  10  Brand             13233 non-null  object
#  11  Product Group     0 non-null      float64
#  12  Taxes             13323 non-null  float64
#  13  Orders            13323 non-null  float64
#  14  Units             13323 non-null  float64
#  15  Refunded          13323 non-null  float64
# ...

# %%
# df['Product Group'].isnull().nunique()

#Drop ( Product Group ) Column -- Null column
df = df.drop('Product Group' , axis=1)

# %%
#Drop ( Internal Name ) Column -- Null column
df = df.drop('Internal Name' ,  axis=1)

# %%
#Drop ( Parent ASIN ) Column -- Null column
df = df.drop('Parent ASIN' , axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13324 entries, 0 to 13323
# Data columns (total 35 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              13323 non-null  datetime64[ns]
#  1   Title             13233 non-null  object
#  2   Account Title     13323 non-null  object
#  3   Market Place      13323 non-null  object
#  4   SKU               13323 non-null  object
#  5   FNSKU             13323 non-null  object
#  6   ASIN              13284 non-null  object
#  7   Parent ASIN       2130 non-null   object
#  8   Is Parent         13323 non-null  float64
#  9   Brand             13233 non-null  object
#  10  Taxes             13323 non-null  float64
#  11  Orders            13323 non-null  float64
#  12  Units             13323 non-null  float64
#  13  Refunded          13323 non-null  float64
#  14  Refund %          13323 non-null  float64
#  15  Unit Session %    13323 non-null  float64
# ...

# %%
df
# Out:
#             Date                                              Title  \
# 0     2020-10-01  High Absorption Magnesium Citrate Supplements ...
# 1     2020-10-02  High Absorption Magnesium Citrate Supplements ...
# 2     2020-10-03  High Absorption Magnesium Citrate Supplements ...
# 3     2020-10-04  High Absorption Magnesium Citrate Supplements ...
# 4     2020-10-05  High Absorption Magnesium Citrate Supplements ...
# ...          ...                                                ...
# 13319 2021-03-28  Gélules biodisponibles du complexe de curcumin...
# 13320 2021-03-29  Gélules biodisponibles du complexe de curcumin...
# 13321 2021-03-30  Gélules biodisponibles du complexe de curcumin...
# 13322 2021-03-31  Gélules biodisponibles du complexe de curcumin...
# 13323        NaT                                                NaN
#
#       Account Title Market Place                             SKU       FNSKU  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                    1
# Title                  91
# Account Title           1
# Market Place            1
# SKU                     1
# FNSKU                   1
# ASIN                   40
# Parent ASIN         11194
# Is Parent               1
# Brand                  91
# Taxes                   1
# Orders                  1
# Units                   1
# Refunded                1
# Refund %                1
# Unit Session %          1
# Promo Units             1
# Organic Units           1
# Per Unit Revenue     1328
# Revenue                 0
# COGS                    1
# FBA Fees                1
# Promo Amount            1
# Sessions                1
# Page Views              1
# Impressions             1
# Clicks                  1
# PPC Orders              1
# PPC Sales               1
# PPC Cost                1
# PPC Conv                1
# OOE                     1
# Net Profit              1
# Net Margin              1
# Net ROI                 1
# dtype: int64

# %%
df['Per Unit Revenue'].value_counts()
# Out:
# Per Unit Revenue
# 19.99    889
# 20.99    432
# 22.99    344
# 21.99    258
# 16.99    212
#         ...
# 15.05      1
# 13.11      1
# 15.94      1
# 14.59      1
# 10.16      1
# Name: count, Length: 1483, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13324 entries, 0 to 13323
# Data columns (total 35 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              13323 non-null  datetime64[ns]
#  1   Title             13233 non-null  object
#  2   Account Title     13323 non-null  object
#  3   Market Place      13323 non-null  object
#  4   SKU               13323 non-null  object
#  5   FNSKU             13323 non-null  object
#  6   ASIN              13284 non-null  object
#  7   Parent ASIN       2130 non-null   object
#  8   Is Parent         13323 non-null  float64
#  9   Brand             13233 non-null  object
#  10  Taxes             13323 non-null  float64
#  11  Orders            13323 non-null  float64
#  12  Units             13323 non-null  float64
#  13  Refunded          13323 non-null  float64
#  14  Refund %          13323 non-null  float64
#  15  Unit Session %    13323 non-null  float64
# ...

# %%
df['Parent ASIN'].isnull().sum()
# Out:
# np.int64(11194)

# %%
df['ASIN'].unique()
# Out:
# array(['B01GU9QLZC', 'B01GU9P0M2', 'B01GU8L68A', 'B07CXYM3H5',
#        'B07CZ1P4BM', 'B07F6FJPQJ', 'B07F838ZVV', 'B07CGSXNH4',
#        'B07CXYWF66', 'B07CY19DMQ', 'B07GBFMRMR', 'B07GH48YC6',
#        'B07GWNXM53', 'B07GH48YD7', 'B07H36MLFB', 'B07HDCS5R1',
#        'B07JVPP2XF', 'B07JBP4X9H', 'B07JBC3GWM', 'B07JCGX3CG',
#        'B07KB28H4B', 'B07KPP2V98', 'B07CXWG8Z9', 'B07MW9GTSR',
#        'B07NXST2Q9', 'B07NXTVSNR', 'B07NYQ3X5R', 'B07P1T8J4P',
#        'B07P5833LZ', 'B07P57TCTL', 'B07PH3WCF3', 'B07PH2191C',
#        'B07PH3X8RV', 'B07PT8N8GP', 'B07QXPNGQJ', 'B01BSQQBZW',
#        'B01M3U8Y9M', 'B07R5ZHBRJ', nan, 'B07RBWFM1T', 'B07WW7DRQQ',
#        'B07WV3QJLD', 'B07YWZ86BM', 'B07Z9FS699', 'B07Z9FM321',
#        'B082J2ZH9Z', 'B082MMPBNG', 'B083V4MH39', 'B08475TXQ6',
#        'B0847RMCL2', 'B084ZLR2D9', 'B084ZMSZ6J', 'B08576VCZW',
#        'B01H1WPOF0', 'B08HZGF7B4', 'B08J19XXFL', 'B08K9BNFS7',
#        'B08K9D3BJL', 'B08K99KS8Z', 'B08KDT2NB5', 'B08QJP9DZH',
# ...

# %%
df['Parent ASIN'].value_counts()
# Out:
# Parent ASIN
# B08P3HP9MH    417
# B08Q4FNGYQ    417
# B092ZXC3XB    376
# B08SWNCMFM    332
# B0913DH4Y1    329
# B0929721G7    259
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13324 entries, 0 to 13323
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              13323 non-null  datetime64[ns]
#  1   Title             13233 non-null  object
#  2   Account Title     13323 non-null  object
#  3   Market Place      13323 non-null  object
#  4   SKU               13323 non-null  object
#  5   FNSKU             13323 non-null  object
#  6   ASIN              13284 non-null  object
#  7   Is Parent         13323 non-null  float64
#  8   Brand             13233 non-null  object
#  9   Taxes             13323 non-null  float64
#  10  Orders            13323 non-null  float64
#  11  Units             13323 non-null  float64
#  12  Refunded          13323 non-null  float64
#  13  Refund %          13323 non-null  float64
#  14  Unit Session %    13323 non-null  float64
#  15  Promo Units       13323 non-null  float64
# ...

# %%
df[['PPC Orders'	, 'PPC Sales' , 	'PPC Cost' , 	'PPC Conv' , 	'OOE' ,	'Net Profit' , 	'Net Margin' ,	'Net ROI']].describe()
# Out:
#          PPC Orders     PPC Sales      PPC Cost      PPC Conv      OOE  \
# count  13323.000000  13323.000000  13323.000000  13323.000000  13323.0
# mean       2.331757     51.895073    -15.246775      0.144013      0.0
# std        4.106758     94.217849     26.139957      0.258420      0.0
# min        0.000000      0.000000  -1064.850000      0.000000      0.0
# 25%        0.000000      0.000000    -17.230000      0.000000      0.0
# 50%        1.000000     18.170000     -6.330000      0.076900      0.0
# 75%        3.000000     63.610000     -1.140000      0.200000      0.0
# max      135.000000   2875.440000      0.000000      6.000000      0.0
#
#          Net Profit    Net Margin       Net ROI
# count  13323.000000  1.332300e+04  13323.000000
# mean      61.224216  2.414762e+11      0.294288
# std      110.080049  1.278643e+14      0.308586
# min     -486.310000 -8.702340e+15     -2.940700
# 25%        5.350000  7.945000e-02      0.115350
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13324 entries, 0 to 13323
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              13323 non-null  datetime64[ns]
#  1   Title             13233 non-null  object
#  2   Account Title     13323 non-null  object
#  3   Market Place      13323 non-null  object
#  4   SKU               13323 non-null  object
#  5   FNSKU             13323 non-null  object
#  6   ASIN              13284 non-null  object
#  7   Is Parent         13323 non-null  float64
#  8   Brand             13233 non-null  object
#  9   Taxes             13323 non-null  float64
#  10  Orders            13323 non-null  float64
#  11  Units             13323 non-null  float64
#  12  Refunded          13323 non-null  float64
#  13  Refund %          13323 non-null  float64
#  14  Unit Session %    13323 non-null  float64
#  15  Promo Units       13323 non-null  float64
# ...
